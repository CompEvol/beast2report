# %% [markdown]
# # Code Coverage of Beast 2 Unit tests
#
# author: Walter Xie
#
# date: 30 May 2016
#
# The report is generated by Interllij [code coverage](https://www.jetbrains.com/help/idea/2016.1/code-coverage.html), and the final report is [here](code_coverage/index.html).
